# %%
import torch
from torch.utils.data import DataLoader
from importlib import reload
from torch import nn

# %%
from models.SeqLabeling import RNNModel
from utils.dataOrder import ArxivClassify

# %%
from allennlp.modules.elmo import Elmo, batch_to_ids

# %%
options_file = "https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_options.json"
weight_file = "https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/2x4096_512_2048cnn_2xhighway/elmo_2x4096_512_2048cnn_2xhighway_weights.hdf5"

# %%
elmo = Elmo(options_file, weight_file, 2, dropout=0)
# Out:
# 03/12/2019 15:04:33 - INFO - allennlp.modules.elmo -   Initializing ELMo

# %%
print(help(Elmo))
# Out:
# Help on class Elmo in module allennlp.modules.elmo:
#
# class Elmo(torch.nn.modules.module.Module)
#  |  Elmo(options_file: str, weight_file: str, num_output_representations: int, requires_grad: bool = False, do_layer_norm: bool = False, dropout: float = 0.5, vocab_to_cache: List[str] = None, keep_sentence_boundaries: bool = False, scalar_mix_parameters: List[float] = None, module: torch.nn.modules.module.Module = None) -> None
#  |
#  |  Compute ELMo representations using a pre-trained bidirectional language model.
#  |
#  |  See "Deep contextualized word representations", Peters et al. for details.
#  |
#  |  This module takes character id input and computes ``num_output_representations`` different layers
#  |  of ELMo representations.  Typically ``num_output_representations`` is 1 or 2.  For example, in
#  |  the case of the SRL model in the above paper, ``num_output_representations=1`` where ELMo was included at
# ...

# %%
from models import SeqLabeling

# %%
model = RNNModel(emdSize=1024,nlayers=1,nhid=1024,noutput=3)
# Out:
# /home/farhood/anaconda3/envs/torch/lib/python3.7/site-packages/torch/nn/modules/rnn.py:46: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))

# %%
from utils import dataOrder
reload(dataOrder)
ds = dataOrder.ArxivClassify(path='../Data/arXiv/test.txt')#,word_to_index='../Data/arXiv/dic.txt')
# Out:
# from data: data loaded

# %%
dataloader = DataLoader(ds,batch_size=7,shuffle=True, num_workers=1)

# %%
for i_batch, batch in enumerate(dataloader):
#     print(batch['data'].size())
#     b = [a[i] for i in range(30) for a in batch['data']]
    b = list(map(list, zip(*batch['data'])))
#     for i in b: print (i)
    d = batch_to_ids(b)
    print(batch['lengths'])
    for i in batch['data']:
        print(i)
    print(d.size())
#     for i in batch['data']:
#         print(i)
#     print(batch)
    break
# Out:
# tensor([30, 30, 30, 30, 30, 30, 30])
# ('If', 'Species', 'In', 'Rastrigin', 'In', 'Numerical', 'Recently,')
# ('every', 'cooperate', 'this', 'and', 'the', 'results', 'the')
# ('active', 'in', 'approach,', 'Rosenbrock', 'infrared', 'were', 'long')
# ('molecule', 'abundance', 'epistemic', 'functions', 'domain', 'used', 'short-term')
# ('involved', 'of', 'uncertainty', '', 'the', 'to', 'memory')
# ('in', 'resources,', 'is', '', 'magnetic', 'explain', 'neural')
# ('the', 'while', 'expressed', '', 'moment', 'effects', 'network')
# ('ensemble', 'they', 'more', '', 'turns', 'of', '(LSTM)')
# ('is', 'behave', 'cautiously', '', 'out', 'the', 'has')
# ('`charged', 'antagonistically', 'via', '', 'to', 'overtaking', 'attracted')
# ("for'", 'in', 'lower', '', 'be', 'manoeuvre', 'wide')
# ('then', 'scarcity', 'and', '', 'a', 'on', 'interest')
# ('in', '', 'upper', '', 'vector', 'the', 'due')
# ('existing', '', 'expectations', '', 'with', 'main', 'to')
# ...

# %%
print(elmo(d)['elmo_representations'][0].size())
# Out:
# torch.Size([7, 13, 1024])

# %%
issubclass(type(elmo),nn.Module)
# Out:
# True

# %%
a = [['hello','my','friends'],['Hel']]
print(batch_to_ids([a[0]]).size())
print(batch_to_ids(a).size())
# Out:
# torch.Size([1, 3, 50])
# torch.Size([2, 3, 50])
